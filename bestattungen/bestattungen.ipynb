# %%
import requests
from bs4 import BeautifulSoup

html = requests.get('https://www.bestattungen.de/verzeichnis.html').text

soup = BeautifulSoup(html)

linkes = []

possible_links = soup.find_all('a')

for link in possible_links:
    if link.has_attr('href'):
        linkes.append(link.attrs['href'])
#        print (link.attrs['href'])

# %%
from pandas import DataFrame

df_link = DataFrame (linkes, columns = ['path'])
df_link = df_link.drop_duplicates()
df_link.shape
# Out:
# (36, 1)

# %%
url_top = 'https://www.bestattungen.de'

df_combine = df_link[df_link['path'].str.contains('/verzeichnis/bestatter')]
df_combine = df_combine.drop(df_combine.index[-1])
df_combine['domain'] = url_top
df_combine['url'] = df_combine['domain'] + df_combine['path']
df_combine.shape
# Out:
# (16, 3)

# %%
df_combine
# Out:
#                                                  path  \
# 18  /verzeichnis/bestatter-in-baden-wuerttemberg.html
# 19              /verzeichnis/bestatter-in-bayern.html
# 20              /verzeichnis/bestatter-in-berlin.html
# 21         /verzeichnis/bestatter-in-brandenburg.html
# 22              /verzeichnis/bestatter-in-bremen.html
# 23             /verzeichnis/bestatter-in-hamburg.html
# 24              /verzeichnis/bestatter-in-hessen.html
# 25  /verzeichnis/bestatter-in-mecklenburg-vorpomme...
# 26       /verzeichnis/bestatter-in-niedersachsen.html
# 27  /verzeichnis/bestatter-in-nordrhein-westfalen....
# 28     /verzeichnis/bestatter-in-rheinland-pfalz.html
# 29            /verzeichnis/bestatter-im-saarland.html
# 30             /verzeichnis/bestatter-in-sachsen.html
# 31      /verzeichnis/bestatter-in-sachsen-anhalt.html
# 32  /verzeichnis/bestatter-in-schleswig-holstein.html
# 33          /verzeichnis/bestatter-in-thueringen.html
#
#                          domain  \
# 18  https://www.bestattungen.de
# 19  https://www.bestattungen.de
# 20  https://www.bestattungen.de
# 21  https://www.bestattungen.de
# 22  https://www.bestattungen.de
# 23  https://www.bestattungen.de
# 24  https://www.bestattungen.de
# 25  https://www.bestattungen.de
# 26  https://www.bestattungen.de
# 27  https://www.bestattungen.de
# 28  https://www.bestattungen.de
# 29  https://www.bestattungen.de
# 30  https://www.bestattungen.de
# 31  https://www.bestattungen.de
# 32  https://www.bestattungen.de
# 33  https://www.bestattungen.de
#
#                                                   url
# 18  https://www.bestattungen.de/verzeichnis/bestat...
# 19  https://www.bestattungen.de/verzeichnis/bestat...
# 20  https://www.bestattungen.de/verzeichnis/bestat...
# 21  https://www.bestattungen.de/verzeichnis/bestat...
# 22  https://www.bestattungen.de/verzeichnis/bestat...
# 23  https://www.bestattungen.de/verzeichnis/bestat...
# 24  https://www.bestattungen.de/verzeichnis/bestat...
# 25  https://www.bestattungen.de/verzeichnis/bestat...
# 26  https://www.bestattungen.de/verzeichnis/bestat...
# 27  https://www.bestattungen.de/verzeichnis/bestat...
# 28  https://www.bestattungen.de/verzeichnis/bestat...
# 29  https://www.bestattungen.de/verzeichnis/bestat...
# 30  https://www.bestattungen.de/verzeichnis/bestat...
# 31  https://www.bestattungen.de/verzeichnis/bestat...
# 32  https://www.bestattungen.de/verzeichnis/bestat...
# 33  https://www.bestattungen.de/verzeichnis/bestat...

# %%
import shutil
from os import makedirs

bundesland_local = 'bestattungen/bundesland/'

makedirs(bundesland_local, exist_ok = True)
shutil.rmtree(bundesland_local)
makedirs(bundesland_local, exist_ok = True)

# %%
for index, row in df_combine.iterrows():
    
    url = row['url']
#    print('Downloading :', url)
    resp = requests.get(url)
    
    fname = bundesland_local + str(index) + '.html'
#    print('Saving: ', fname)
    
    with open(fname, 'w') as wf:
        wf.write(resp.text)

print('\n')
print('done...')
# Out:
# done...

# %%
from glob import glob
from os.path import join

html_filenames = glob(join(bundesland_local, '*.html'))

# %%
region_local = 'bestattungen/region/'

makedirs(region_local, exist_ok = True)
shutil.rmtree(region_local)
makedirs(region_local, exist_ok = True)

# %%
from urllib.parse import urljoin

for hname in html_filenames:
    
    with open(hname, 'r') as rf:
        txt = rf.read()
        soup = BeautifulSoup(txt, 'lxml')
        
        for active in soup.find_all('ul', {"class": "menu_sub"}):
            active_link = active.find('li')
#            print (active_link)

            for each in active_link.find_all('li'):
                href = each.find('a').attrs['href']
                url = urljoin(url_top, href)
#                print('Downloading: ', url)
                resp = requests.get(url)

                fn = href.replace('/', '-').strip('-')
                full_fname = join(region_local, fn)
#                print('Saving ', full_fname)
                with open(full_fname, 'w') as wf:
                    wf.write(resp.text)

print('\n')
print('done...')
# Out:
# done...

# %%
import re

regex = re.compile(r'[\n\r\t]')

import pandas as pd
import glob
import os.path

df_bestattungen = pd.DataFrame()

count = 0

for file_name in glob.glob(os.path.join(region_local, '*.html')):
    with open(file_name) as html_file:
        soup = BeautifulSoup(html_file)
#        print (file_name)
        
        for i in soup.find('div', {'page'}):
            company_all = soup.find_all('div')
#            print('Number of cards found       : ', len(company_all))
            count += len(company_all)
#            print('Total Number of cards found : ', count)
#            print('\n')
#            print(company_all)

            for select in company_all:
                company = getattr(select.find('h2'), 'text', None)
#                print(company)

                address = getattr(select.find('div', {'address'}), 'text', None)
#                print (address)

                df_bestattungen = df_bestattungen.append(pd.DataFrame([[company, address]],
                                                                      columns=['Marke', 'Adresse']))

print('\n')
print('Total Number of cards found : ', count)
print('done...')
# Out:
# Total Number of cards found :  42658
# done...

# %%
df_bestattungen.shape
# Out:
# (42658, 2)

# %%
df_bestattungen.reset_index(drop = True, inplace = True)
#df_bestattungen.head(25)

# %%
df_bestattungen = df_bestattungen[df_bestattungen['Marke'].notna()]
df_bestattungen = df_bestattungen[df_bestattungen['Adresse'].notna()]
df_bestattungen = df_bestattungen.drop_duplicates('Marke', keep='first')
#df_bestattungen.head(25)

# %%
df_bestattungen[['Strasse']] = df_bestattungen.Adresse.str.extract('(.+)', expand = True)
df_bestattungen[['Plz', 'Ort']] = df_bestattungen.Adresse.str.extract('([0-9]{5})[ ](.+)', expand = True)
#df_bestattungen.head(25)

# %%
df_bestattungen['Plz'] = df_bestattungen['Plz'].astype(int)
df_bestattungen['Plz'] = ["%05d" % n for n in df_bestattungen['Plz']]
#df_bestattungen.head(25)

# %%
df_bestattungen['Source'] = 'https://www.bestattungen.de/verzeichnis.html'
#df_bestattungen.head(25)

# %%
df_bestattungen = df_bestattungen.drop('Adresse', axis = 1)
#df_bestattungen.head(25)

# %%
df_bestattungen['Marke'] = df_bestattungen['Marke'].str.replace('\n',' ')
#df_bestattungen.head(25)

# %%
df_bestattungen
# Out:
#                                                Marke              Strasse  \
# 11                               Bestattungen Horn    Neuhauser Straße 93
# 29                              Bestattungen Merkt          Hauptstr. 136
# 36          Bestattungsinstitut Ella Sichler e. K.       Brunnentalstr. 1
# 42                  Bestattungsinstitut Neipp e.k.    Göldenbühlstraße 15
# 49                       Franz Fetzer Bestattungen        Hauptstraße 142
# ...                                              ...                  ...
# 41597                    Manfred Seiz Bestattungen          Pfarrgasse 10
# 41604                 Marianne Rieder Bestattungen        Ulrichstraße 62
# 41617               Otto Höfle Bestattungsinstitut    Uhinger Straße 51/1
# 41623                    Wilhelm Wolf Bestattungen         Hauptstraße 57
# 41630   Zimmermann Schreinerei + Bestattungs GmbH           Kanalstraße 1
#
#          Plz            Ort                                        Source
# 11     78532     Tuttlingen  https://www.bestattungen.de/verzeichnis.html
# 29     78549    Spaichingen  https://www.bestattungen.de/verzeichnis.html
# 36     78532     Tuttlingen  https://www.bestattungen.de/verzeichnis.html
# 42     78647     Trossingen  https://www.bestattungen.de/verzeichnis.html
# 49     78588      Denkingen  https://www.bestattungen.de/verzeichnis.html
# ...      ...            ...                                           ...
# 41597  73037      Göppingen  https://www.bestattungen.de/verzeichnis.html
# 41604  73033      Göppingen  https://www.bestattungen.de/verzeichnis.html
# 41617  73095   Albershausen  https://www.bestattungen.de/verzeichnis.html
# 41623  73108  Gammelshausen  https://www.bestattungen.de/verzeichnis.html
# 41630  73084         Salach  https://www.bestattungen.de/verzeichnis.html
#
# [599 rows x 5 columns]

# %%
df_bestattungen.to_csv('bestattungen/df_bestattungen_20200605.csv', sep = ';', index = False)

# %%
import pandas as pd

df = pd.read_csv('bestattungen/df_bestattungen_20200605.csv', sep = ';')
df
# Out:
#                                              Marke              Strasse  \
# 0                              Bestattungen Horn    Neuhauser Straße 93
# 1                             Bestattungen Merkt          Hauptstr. 136
# 2         Bestattungsinstitut Ella Sichler e. K.       Brunnentalstr. 1
# 3                 Bestattungsinstitut Neipp e.k.    Göldenbühlstraße 15
# 4                      Franz Fetzer Bestattungen        Hauptstraße 142
# ..                                             ...                  ...
# 594                    Manfred Seiz Bestattungen          Pfarrgasse 10
# 595                 Marianne Rieder Bestattungen        Ulrichstraße 62
# 596               Otto Höfle Bestattungsinstitut    Uhinger Straße 51/1
# 597                    Wilhelm Wolf Bestattungen         Hauptstraße 57
# 598   Zimmermann Schreinerei + Bestattungs GmbH           Kanalstraße 1
#
#        Plz            Ort                                        Source
# 0    78532     Tuttlingen  https://www.bestattungen.de/verzeichnis.html
# 1    78549    Spaichingen  https://www.bestattungen.de/verzeichnis.html
# 2    78532     Tuttlingen  https://www.bestattungen.de/verzeichnis.html
# 3    78647     Trossingen  https://www.bestattungen.de/verzeichnis.html
# 4    78588      Denkingen  https://www.bestattungen.de/verzeichnis.html
# ..     ...            ...                                           ...
# 594  73037      Göppingen  https://www.bestattungen.de/verzeichnis.html
# 595  73033      Göppingen  https://www.bestattungen.de/verzeichnis.html
# 596  73095   Albershausen  https://www.bestattungen.de/verzeichnis.html
# 597  73108  Gammelshausen  https://www.bestattungen.de/verzeichnis.html
# 598  73084         Salach  https://www.bestattungen.de/verzeichnis.html
#
# [599 rows x 5 columns]
